# %%
import pandas as pd, numpy as np, seaborn as sns
import matplotlib.pyplot as plt

# %%
inp0=pd.read_csv("bank_marketing_updated_v1.csv", header=None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
inp0.head()
# Out:
#                      0    1                             2        3   \
# 0     banking marketing  NaN                           NaN      NaN
# 1  customer id and age.  NaN  Customer salary and balance.      NaN
# 2            customerid  age                        salary  balance
# 3                     1   58                        100000     2143
# 4                     2   44                         60000       29
#
#                                                   4                     5   \
# 0                                                NaN                   NaN
# 1  Customer marital status and job with education...                   NaN
# 2                                            marital                jobedu
# 3                                            married   management,tertiary
# 4                                             single  technician,secondary
#
#                                            6        7   \
# ...

# %%
inp0=inp0[2:]

# %%
inp0.head()
# Out:
#            0    1       2        3        4                       5   \
# 2  customerid  age  salary  balance  marital                  jobedu
# 3           1   58  100000     2143  married     management,tertiary
# 4           2   44   60000       29   single    technician,secondary
# 5           3   33  120000        2  married  entrepreneur,secondary
# 6           4   47   20000     1506  married     blue-collar,unknown
#
#          6        7        8     9        10   11         12        13  \
# 2  targeted  default  housing  loan  contact  day      month  duration
# 3       yes       no      yes    no  unknown    5  may, 2017   261 sec
# 4       yes       no      yes    no  unknown    5  may, 2017   151 sec
# 5       yes       no      yes   yes  unknown    5  may, 2017    76 sec
# 6        no       no      yes    no  unknown    5  may, 2017    92 sec
#
#          14     15        16        17        18
# 2  campaign  pdays  previous  poutcome  response
# ...

# %%
header=inp0.iloc[0]
header
# Out:
# 0     customerid
# 1            age
# 2         salary
# 3        balance
# 4        marital
# 5         jobedu
# 6       targeted
# 7        default
# 8        housing
# 9           loan
# 10       contact
# 11           day
# 12         month
# 13      duration
# 14      campaign
# 15         pdays
# 16      previous
# 17      poutcome
# 18      response
# Name: 2, dtype: object

# %%
inp0=inp0[1:]

# %%
inp0.columns=header
inp0.reset_index()
inp0
# Out:
# 2     customerid age  salary balance   marital                  jobedu  \
# 3              1  58  100000    2143   married     management,tertiary
# 4              2  44   60000      29    single    technician,secondary
# 5              3  33  120000       2   married  entrepreneur,secondary
# 6              4  47   20000    1506   married     blue-collar,unknown
# 7              5  33       0       1    single         unknown,unknown
# ...          ...  ..     ...     ...       ...                     ...
# 45209      45207  51   60000     825   married     technician,tertiary
# 45210      45208  71   55000    1729  divorced         retired,primary
# 45211      45209  72   55000    5715   married       retired,secondary
# 45212      45210  57   20000     668   married   blue-collar,secondary
# 45213      45211  37  120000    2971   married  entrepreneur,secondary
#
# 2     targeted default housing loan    contact day      month  \
# ...

# %%
inp0.balance=inp0.balance.astype(int
                  )

# %%
sns.boxplot(inp0.salary)
plt.show()
